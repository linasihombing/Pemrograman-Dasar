# %% [markdown]
# <a href="https://colab.research.google.com/github/linasihombing/Pemrograman-Dasar/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya
# STRING
Nama = "Maulina Sihombing"
Jurusan = "Teknik Elektro"
Program_studi = "Teknik Rekayasa Pembangkit Energi"
Matakuliah = "Pemograman dasar"
# INTEGER (Angka bulat)
Nim = 4232501058
Semester = 3
Umur = 19
# BOOLEAN
Status_lulus = False
# FLOAT (Angka desimal)
Tinggi_badan = 160.2
Berat_badan = 52.47
# LIST
Makanan_favorit = ["Martabak telor", "perkedel kentang", "dimsum"]
# TUPLE
Ttl = ("Batam","01 Agustus 2007")
# DICTIONARY
Social_media = {"Instagram":"@linaa.shmbg_", "GitHub":"linasihombing"}
# --- MEMBUAT TAMPILAN BIODATA ---
# Menggabungkan semua tipe data menggunakan f-string
biodata = f"""
========================================================================
              BIODATA MAHASISWA
========================================================================
Nama Lengkap         : {Nama}
Nim                  : {Nim}
Tempat/tanggal lahir : {', '.join(Ttl)}
Usia                 : {Umur} Tahun
Jurusan              : {Jurusan}
Program studi        : {Program_studi}
Semester             : {Semester}
Mata Kuliah          : {Matakuliah}
Tinggi/berat badan   : {Tinggi_badan}/{Berat_badan}
Status Lulus         : {Status_lulus}
Top 1 food           : {Makanan_favorit[0]}
Top 3 foods          : {', '.join(Makanan_favorit)}
Social media         : {', '.join(f'{k}: {v}' for k, v in Social_media.items())}
========================================================================
"""

print(biodata)
# Out:
# ...
#               BIODATA MAHASISWA
# ...
# Nama Lengkap         : Maulina Sihombing
# Nim                  : 4232501058
# Tempat/tanggal lahir : Batam, 01 Agustus 2007
# Usia                 : 19 Tahun
# Jurusan              : Teknik Elektro
# Program studi        : Teknik Rekayasa Pembangkit Energi
# Semester             : 3
# Mata Kuliah          : Pemograman dasar
# Tinggi/berat badan   : 160.2/52.47
# Status Lulus         : False
# Top 1 food           : Martabak telor
# Top 3 foods          : Martabak telor, perkedel kentang, dimsum
# Social media         : Instagram: @linaa.shmbg_, GitHub: linasihombing
# ...
