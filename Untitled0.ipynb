# %% [markdown]
# <a href="https://colab.research.google.com/github/linasihombing/Pemrograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama = "Maulina Sihombing"
umur = 19
jurusan = "TRPE"
semester = 3
matakuliah = 'Pemograman Dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (matakuliah)
print (status_lulus)
# Out:
# Maulina Sihombing
# 19
# TRPE
# Pemograman Dasar
# False
